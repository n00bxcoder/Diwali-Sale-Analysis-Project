# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('Diwali Sales Data.csv', encoding= 'unicode_escape')

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1      barcode                      bar char (age )
# ...

# %%
df.shape
# Out:
# (11243, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11243 entries, 0 to 11242
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11243 non-null  int64
#  1   Cust_name         11243 non-null  object
#  2   Product_ID        11243 non-null  object
#  3   Gender            11243 non-null  object
#  4   Age Group         11243 non-null  object
#  5   Age               11243 non-null  int64
#  6   Marital_Status    11243 non-null  int64
#  7   State             11243 non-null  object
#  8   Zone              11243 non-null  object
#  9   Occupation        11243 non-null  object
#  10  Product_Category  11243 non-null  object
#  11  Orders            11243 non-null  int64
#  12  Amount            11231 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
#  15  barcode           37 non-null     object
# ...

# %%
df.drop(['Status','unnamed1'],axis = 1, inplace=True )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11243 entries, 0 to 11242
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11243 non-null  int64
#  1   Cust_name         11243 non-null  object
#  2   Product_ID        11243 non-null  object
#  3   Gender            11243 non-null  object
#  4   Age Group         11243 non-null  object
#  5   Age               11243 non-null  int64
#  6   Marital_Status    11243 non-null  int64
#  7   State             11243 non-null  object
#  8   Zone              11243 non-null  object
#  9   Occupation        11243 non-null  object
#  10  Product_Category  11243 non-null  object
#  11  Orders            11243 non-null  int64
#  12  Amount            11231 non-null  float64
#  13  barcode           37 non-null     object
#  14  bar char (age )   27 non-null     object
# dtypes: float64(1), int64(4), object(10)
# memory usage: 1.3+ MB

# %%
pd.isnull(df)
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11238    False      False       False   False      False  False
# 11239    False      False       False   False      False  False
# 11240    False      False       False   False      False  False
# 11241    False      False       False   False      False  False
# 11242    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
pd.isnull(df).sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# barcode             11206
# bar char (age )     11216
# dtype: int64

# %%
df.shape
# Out:
# (11243, 15)

# %%
df.dropna(inplace =True)

# %%
df.shape
# Out:
# (24, 15)

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# barcode             0
# bar char (age )     0
# dtype: int64

# %%
df.to_csv('DIWALI SALES DATA CLEAN.csv', index=False)

# %%
df['Amount']=df['Amount'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 0 to 26
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           24 non-null     int64
#  1   Cust_name         24 non-null     object
#  2   Product_ID        24 non-null     object
#  3   Gender            24 non-null     object
#  4   Age Group         24 non-null     object
#  5   Age               24 non-null     int64
#  6   Marital_Status    24 non-null     int64
#  7   State             24 non-null     object
#  8   Zone              24 non-null     object
#  9   Occupation        24 non-null     object
#  10  Product_Category  24 non-null     object
#  11  Orders            24 non-null     int64
#  12  Amount            24 non-null     int32
#  13  barcode           24 non-null     object
#  14  bar char (age )   24 non-null     object
# dtypes: int32(1), int64(4), object(10)
# memory usage: 2.9+ KB

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'barcode', 'bar char (age )'],
#       dtype='object')

# %% [markdown]
# # EXPLORATION DATA ANALYSIS

# %%
ax = sns.countplot(x= 'Gender' , data=df)

# %%
ax = sns.countplot(x= 'Gender' , data=df)
for bars in ax.containers :
    ax.bar_label(bars)

# %%
df.groupby(['Gender'], as_index = False )['Amount'].sum().sort_values(by='Amount',ascending = False)
# Out:
#   Gender  Amount
# 0      F  378688
# 1      M  190044

# %%
sales_gen =df.groupby(['Gender'], as_index = False )['Amount'].sum().sort_values(by='Amount',ascending = False)
sns.barplot(x='Gender',y ='Amount',data=sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# # FROM THE ABOVE GRAPH WE CAN SEE THAT MOST OF THE SALE IS GENERATED BY FEMALES
# # MOST CUSTUMERS ARE FEMALES AND THE MOST AMOUNT OF MONEY SPEND IS ALSO BY FEMALES

# %% [markdown]
# # ANALYSIS BY AGE

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'barcode', 'bar char (age )'],
#       dtype='object')

# %%
ax = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(data = df, x = 'Age Group', hue ='Gender')

# %%
sales_age=df.groupby(['Age Group'] ,as_index =False)['Amount'].sum().sort_values(by='Amount',ascending =False)
sns.barplot(x='Age Group', y = 'Amount',data=sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# # FROM THIS GRAPH WE CAN SEE MOST OF THE BUYER ARE FROM THE AGE GROUP OF 26-35 AND MOSTLY ARE WOMEN

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'barcode', 'bar char (age )'],
#       dtype='object')

# %% [markdown]
# # STATES

# %%
sales_states= df.groupby(['State'],as_index= False)['Orders'].sum().sort_values(by='Orders',ascending = False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='State',y= 'Orders',data=sales_states)
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
sales_states= df.groupby(['State'],as_index= False)['Amount'].sum().sort_values(by='Amount',ascending = False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='State',y= 'Amount',data=sales_states)
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
# MOST OF THE ORDERS ARE FROM UTTAR PRADESH , MAHARASHTRA , KARNATAKA . IN BOTH NUMBER OF ORDERS WISE AND ACCORDING TO THE 
#AMOUNT SPEND ON THE ORDERS

# %% [markdown]
# # ANALYSIS ON OCCUPATION

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax =sns.countplot(data=df , x= 'Occupation')
for bars in ax.containers :
        ax.bar_label(bars)

# %%
sales_states= df.groupby(['Occupation'],as_index= False)['Amount'].sum().sort_values(by='Amount',ascending = False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='Occupation',y= 'Amount',data=sales_states)
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %%
# TOP BUYER FROM WORKING IN THE IT SECTOR THEN HEALTHCARE AND THEN AVIATION

# %% [markdown]
# # PRODUCT CATEGORY

# %%
sales_states= df.groupby(['Product_Category'],as_index= False)['Amount'].sum().sort_values(by='Amount',ascending = False).head(10)
sns.set(rc={'figure.figsize':(20,5)})

sns.barplot(x='Product_Category',y= 'Amount',data=sales_states)
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax =sns.countplot(data=df , x= 'Product_Category')
for bars in ax.containers :
        ax.bar_label(bars)

# %%
#MOST SOLD PRODUCTS ARE FROM FOOD ,CLOTHING AND ELECTRONICS

# %%
sales_states= df.groupby(['Product_ID'],as_index= False)['Orders'].sum().sort_values(by='Orders',ascending = False).head(10)
sns.set(rc={'figure.figsize':(20,5)})

sns.barplot(x='Product_ID',y= 'Orders',data=sales_states)
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# WOMEN FROM THE AGE GROUP 26-35 FRPM UP , MAHARASHTRA AND KARNATAKS WORKING IN IT , HEALTHCARE ARE MORE LIKELY TO BUY PRODUCTS
# FROM FOOD , CLOTHING AND ELECTRONICS CATEGORY
